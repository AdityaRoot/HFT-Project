# %%
from base_model import BaselineModel
import pandas as pd

input_csv = "../data/bybit_quotes_2024-06-14_1000BEERUSDT.csv"
sample_df = pd.read_csv(input_csv)
# sample_df = sample_df.head(100)

model = BaselineModel(
    quote_df = sample_df,
    starting_usd=1000,
)
# Out:
# ===Cleaning Quotes===
# Original shape: (798817, 8)
# After dropping NaNs: (798817, 8)

# %%
model.sample_quotes(head=1000)
model.plot_quotes()
